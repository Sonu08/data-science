# %% [markdown]
# # IMDB Movie Data Analytics

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('title_akas.tsv', sep='\t')
# Out:
# C:\Users\Sonu Singh\AppData\Local\Temp\ipykernel_22460\1194148522.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('title_akas.tsv', sep='\t')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33089259 entries, 0 to 33089258
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ GB

# %%
df1.shape
# Out:
# (33089259, 8)

# %%
df1.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
df2 = pd.read_csv('title_basics.tsv', sep='\t')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11902469 entries, 0 to 11902468
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 544.9+ MB

# %%
df2.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0031983,tt0050419,tt0053137,tt0072308
# 1  tt0071877,tt0117057,tt0038355,tt0037382
# 2  tt0049189,tt0054452,tt0056404,tt0057345
# 3  tt0080455,tt0072562,tt0077975,tt0078723
# 4  tt0083922,tt0050976,tt0050986,tt0060827

# %%
df3 = pd.read_csv('title_another_basics.tsv', sep='\t')
# Out:
# C:\Users\Sonu Singh\AppData\Local\Temp\ipykernel_22460\2913802974.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('title_another_basics.tsv', sep='\t')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9202163 entries, 0 to 9202162
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 631.9+ MB

# %%
df3.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df4 = pd.read_csv('title_principals.tsv', sep='\t')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51917711 entries, 0 to 51917710
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   tconst      object
#  1   ordering    int64
#  2   nconst      object
#  3   category    object
#  4   job         object
#  5   characters  object
# dtypes: int64(1), object(5)
# memory usage: 2.3+ GB

# %%
df4.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
df5 = pd.read_csv('title_ratings.tsv', sep='\t')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259525 entries, 0 to 1259524
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1259525 non-null  object
#  1   averageRating  1259525 non-null  float64
#  2   numVotes       1259525 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.8+ MB

# %%
df5.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1909
# 1  tt0000002            5.8       256
# 2  tt0000003            6.5      1709
# 3  tt0000004            5.6       168
# 4  tt0000005            6.2      2523

# %%
df001 = pd.merge(df4, df5)

# %%
df001.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters  averageRating  numVotes
# 0   ["Self"]            5.7      1909
# 1         \N            5.7      1909
# 2         \N            5.7      1909
# 3         \N            5.8       256
# 4         \N            5.8       256

# %%
df001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10466425 entries, 0 to 10466424
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   tconst         object
#  1   ordering       int64
#  2   nconst         object
#  3   category       object
#  4   job            object
#  5   characters     object
#  6   averageRating  float64
#  7   numVotes       int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 718.7+ MB

# %%
df002 = pd.merge(df001, df3)

# %%
df002.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters  averageRating  numVotes titleType            primaryTitle  \
# 0   ["Self"]            5.7      1909     short              Carmencita
# 1         \N            5.7      1909     short              Carmencita
# 2         \N            5.7      1909     short              Carmencita
# 3         \N            5.8       256     short  Le clown et ses chiens
# 4         \N            5.8       256     short  Le clown et ses chiens
#
#             originalTitle isAdult startYear endYear runtimeMinutes  \
# ...

# %%
df003 = pd.merge(df002, df2)

# %%
df003.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10463768 entries, 0 to 10463767
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   tconst             object
#  1   ordering           int64
#  2   nconst             object
#  3   category           object
#  4   job                object
#  5   characters         object
#  6   averageRating      float64
#  7   numVotes           int64
#  8   titleType          object
#  9   primaryTitle       object
#  10  originalTitle      object
#  11  isAdult            object
#  12  startYear          object
#  13  endYear            object
#  14  runtimeMinutes     object
#  15  genres             object
#  16  primaryName        object
#  17  birthYear          object
#  18  deathYear          object
#  19  primaryProfession  object
#  20  knownForTitles     object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.7+ GB

# %%
df003.head()
# Out:
#       tconst  ordering     nconst  category job characters  averageRating  \
# 0  tt0000001         1  nm1588970      self  \N   ["Self"]            5.7
# 1  tt0000001         2  nm0005690  director  \N         \N            5.7
# 2  tt0000005         3  nm0005690  director  \N         \N            6.2
# 3  tt0000006         1  nm0005690  director  \N         \N            5.1
# 4  tt0000007         3  nm0005690  director  \N         \N            5.4
#
#    numVotes titleType                                 primaryTitle  ...  \
# 0      1909     short                                   Carmencita  ...
# 1      1909     short                                   Carmencita  ...
# 2      2523     short                             Blacksmith Scene  ...
# 3       173     short                            Chinese Opium Den  ...
# 4       787     short  Corbett and Courtney Before the Kinetograph  ...
#
#   isAdult startYear endYear runtimeMinutes             genres  \
# ...

# %%
df004 = pd.merge(df003, df1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df004 = pd.merge(df003, df1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
# ...
